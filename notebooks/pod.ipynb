# %%
import numpy as np

def is_float(string):
    """ True if given string is float else False"""
    try:
        return float(string)
    except ValueError:
        return False

data = []
with open('/home/colin/hdd/workspace/datasets/glider/training_cases_1e3/data/case_data.dat', 'r') as f:
    d = f.readlines()
    for i in d:
        k = i.rstrip().split(",")
        data.append([float(i) if is_float(i) else i for i in k])

# %%
data
# Out:
# [['# case_name geom_name alt_kft Re_L M_inf alpha_deg beta_deg CD'],
#  ['case_000 geom_0000      9.8444882  3.4772524e+08     0.18993642              0              0    0.007780487'],
#  ['case_001 geom_0001      25.266903  1.3061028e+08     0.20117514              0              0   0.0063920653'],
#  ['case_002 geom_0002       25.84983    1.84138e+08     0.47384506              0              0   0.0031941525'],
#  ['case_003 geom_0003      14.403603  3.0252477e+08    0.085578881              0              0       0.125281'],
#  ['case_004 geom_0004      19.501669   4.835245e+08      0.7854498              0              0    0.029295749'],
#  ['case_005 geom_0005      23.510822  2.7375451e+08     0.35942214              0              0   0.0061920276'],
#  ['case_006 geom_0006      42.603425       93967788     0.35668335              0              0   0.0049519557'],
# ...
